# %% [markdown]
# ### Q1. Scenario: A company wants to analyze the sales performance of its products in different regions. They have collected the following data:
#    Region A: [10, 15, 12, 8, 14]
#    Region B: [18, 20, 16, 22, 25]
#    Calculate the mean sales for each region.

# %% [markdown]
# ### Ans:- Region A:
# - Sales: [10, 15, 12, 8, 14]
# - Total sales in Region A = 10 + 15 + 12 + 8 + 14 = 59
# - Number of data points in Region A = 5
# - Mean sales in Region A = Total sales / Number of data points = 59 / 5 = 11.8
#
# Region B:
# - Sales: [18, 20, 16, 22, 25]
# - Total sales in Region B = 18 + 20 + 16 + 22 + 25 = 101
# - Number of data points in Region B = 5
# - Mean sales in Region B = Total sales / Number of data points = 101 / 5 = 20.2
#
# Therefore, the mean sales for Region A is 11.8 and for Region B is 20.2.

# %% [markdown]
# ### 2. Scenario: A survey is conducted to measure customer satisfaction on a scale of 1 to 5. The data collected is as follows:
#    [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#
#  Calculate the mode of the survey responses.

# %% [markdown]
# ### Ans:- The data set is [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]. Let's find the mode:
#
# Step 1: Count the frequency of each value in the data set.
#
# - The value 2 appears 2 times.
# - The value 3 appears 2 times.
# - The value 4 appears 3 times.
# - The value 5 appears 3 times.
#
# ### Step 2: Identify the value(s) with the highest frequency. In this case, both 4 and 5 have the highest frequency, which is 3.
#
# Therefore, the mode of the survey responses is 4 and 5, as both values appear most frequently in the data set.

# %% [markdown]
# ### 3. Scenario: A company wants to compare the salaries of two departments. The salary data for Department A and Department B are as follows:
#    Department A: [5000, 6000, 5500, 7000]
#
#    Department B: [4500, 5500, 5800, 6000, 5200]
#
#    Calculate the median salary for each department.

# %% [markdown]
# ### Ans:- Department A:
# Salaries: [5000, 6000, 5500, 7000]
#
# Arranging the salaries in ascending order: [5000, 5500, 6000, 7000]
#
# Since the number of data points is odd (4), the median is the middle value.
# Median salary in Department A = 5500
#
# Department B:
#
# Salaries: [4500, 5500, 5800, 6000, 5200]
#
# Arranging the salaries in ascending order: [4500, 5200, 5500, 5800, 6000]
#
# Since the number of data points is odd (5), the median is the middle value.
# Median salary in Department B = 5500
#
# Therefore, the median salary for Department A is 5500, and for Department B is also 5500.

# %% [markdown]
# ### 4. Scenario: A data analyst wants to determine the variability in the daily stock prices of a company. The data collected is as follows:
#    [25.5, 24.8, 26.1, 25.3, 24.9]
#
#    Calculate the range of the stock prices.

# %% [markdown]
# ### Ans:-the data set is [25.5, 24.8, 26.1, 25.3, 24.9]. Let's find the range:
#
# Step 1: Find the highest value.
#
# Highest value = 26.1
#
# Step 2: Find the lowest value.
#
# Lowest value = 24.8
#
# Step 3: Calculate the range.
#
# Range = Highest value - Lowest value = 26.1 - 24.8 = 1.3
#
# Therefore, the range of the stock prices is 1.3.

# %% [markdown]
# ### 5. Scenario: A study is conducted to compare the performance of two different teaching methods. The test scores of the students in each group are as follows:
#
#   Group A: [85, 90, 92, 88, 91]
#
#   Group B: [82, 88, 90, 86, 87]
#
#    Perform a t-test to determine if there is a significant difference in the mean scores between the two groups.

# %% [markdown]
# ### Ans:- Group A: [85, 90, 92, 88, 91]
# Group B: [82, 88, 90, 86, 87]
#
# Step 1: Calculate the means of both groups.
#
# Mean of Group A = (85 + 90 + 92 + 88 + 91) / 5 = 89.2
#
# Mean of Group B = (82 + 88 + 90 + 86 + 87) / 5 = 86.6
#
# Step 2: Calculate the standard deviations of both groups.
#
# Standard deviation of Group A = 2.966
#
# Standard deviation of Group B = 2.073
#
# Step 3: Calculate the t-statistic using the formula:
#
# t = (mean of Group A - mean of Group B) / sqrt((s1^2/n1) + (s2^2/n2))
#
# where s1 and s2 are the standard deviations, n1 and n2 are the sample sizes.
#
# * t = (89.2 - 86.6) / sqrt((2.966^2/5) + (2.073^2/5))
# * t = 2.6 / sqrt(1.773 + 0.850)
# * t = 2.6 / sqrt(2.623)
# * t = 2.6 / 1.619
# * t ≈ 1.605
#
# Step 4: Determine the degrees of freedom (df) using the formula:
# * df = n1 + n2 - 2
# * df = 5 + 5 - 2
# * df = 8
#
# Step 5: Determine the critical t-value or p-value for the desired significance level (alpha) and degrees of freedom. Assuming a significance level of 0.05 (5%), we can consult a t-table or use statistical software to find the critical t-value or p-value.
#
# Step 6: Compare the calculated t-statistic with the critical t-value or p-value to make a decision.

# %% [markdown]
# ### 6. Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
#
#    Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#
#    Sales (in thousands): [25, 30, 28, 20, 26]
#
#    Calculate the correlation coefficient between advertising expenditure and sales.

# %% [markdown]
# ### Ans:-The Pearson correlation coefficient measures the strength and direction of the linear relationship between two variables.
#
# Let's calculate the correlation coefficient using the given data:
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Advertising Expenditure = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of Sales = (25 + 30 + 28 + 20 + 26) / 5 = 25.8
#
# Step 2: Calculate the differences from the means for each data point.
#
# Differences for Advertising Expenditure = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8]
#
# Differences for Sales = [25 - 25.8, 30 - 25.8, 28 - 25.8, 20 - 25.8, 26 - 25.8]
#
# Step 3: Calculate the product of the differences for each data point.
#
# Product of Differences = (10 - 11.8) * (25 - 25.8) + (15 - 11.8) * (30 - 25.8) + (12 - 11.8) * (28 - 25.8) + (8 - 11.8) * (20 - 25.8) + (14 - 11.8) * (26 - 25.8)
#
# Step 4: Calculate the sum of the products of differences.
#
# Sum of Products = (10 - 11.8) * (25 - 25.8) + (15 - 11.8) * (30 - 25.8) + (12 - 11.8) * (28 - 25.8) + (8 - 11.8) * (20 - 25.8) + (14 - 11.8) * (26 - 25.8)
#
# Step 5: Calculate the standard deviation of both variables.
#
# Standard deviation of Advertising Expenditure = 2.588
#
# Standard deviation of Sales = 3.114
#
# Step 6: Calculate the correlation coefficient using the formula:
#
# Correlation Coefficient = Sum of Products / (Standard deviation of Advertising Expenditure * Standard deviation of Sales)
#
# Correlation Coefficient = Sum of Products / (2.588 * 3.114)
#
# Therefore, the correlation coefficient between advertising expenditure and sales is equal to the value obtained by dividing the sum of products by (2.588 * 3.114).

# %% [markdown]
# ### 7. Scenario: A survey is conducted to measure the heights of a group of people. The data collected is as follows:
#    [160, 170, 165, 155, 175, 180, 170]
#
#    Calculate the standard deviation of the heights.

# %% [markdown]
# ### Ans:- Step 1: Find the mean of the heights.
#
# Mean = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7 = 166.43 (rounded to two decimal places)
#
# Step 2: Calculate the differences between each height and the mean.
#
# Differences = [(160 - 166.43), (170 - 166.43), (165 - 166.43), (155 - 166.43), (175 - 166.43), (180 - 166.43), (170 - 166.43)]
#
# Step 3: Square each difference.
#
# Squared differences = [(-6.43)^2, (3.57)^2, (-1.43)^2, (-11.43)^2, (8.57)^2, (13.57)^2, (3.57)^2]
#
# Step 4: Calculate the sum of the squared differences.
#
# Sum of squared differences = (-6.43)^2 + (3.57)^2 + (-1.43)^2 + (-11.43)^2 + (8.57)^2 + (13.57)^2 + (3.57)^2
#
# Step 5: Divide the sum of squared differences by the number of data points (n).
#
# Variance = Sum of squared differences / n
#
# Step 6: Calculate the square root of the variance to obtain the standard deviation.
#
# Standard deviation = √Variance

# %% [markdown]
# ### 8. Scenario: A company wants to analyze the relationship between employee tenure and job satisfaction. The data collected is as follows:
#
#   Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
#
#   Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
#   Perform a linear regression analysis to predict job satisfaction based on employee tenure.

# %% [markdown]
# ### Ans:-Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
#
# Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Employee Tenure = (2 + 3 + 5 + 4 + 6 + 2 + 4) / 7 = 3.57 (rounded to two decimal places)
#
# Mean of Job Satisfaction = (7 + 8 + 6 + 9 + 5 + 7 + 6) / 7 = 6.86 (rounded to two decimal places)
#
# Step 2: Calculate the differences from the means for each data point.
#
# Differences for Employee Tenure = [2 - 3.57, 3 - 3.57, 5 - 3.57, 4 - 3.57, 6 - 3.57, 2 - 3.57, 4 - 3.57]
#
# Differences for Job Satisfaction = [7 - 6.86, 8 - 6.86, 6 - 6.86, 9 - 6.86, 5 - 6.86, 7 - 6.86, 6 - 6.86]
#
# Step 3: Calculate the product of the differences for each data point.
#
# Product of Differences = (2 - 3.57) * (7 - 6.86) + (3 - 3.57) * (8 - 6.86) + (5 - 3.57) * (6 - 6.86) + (4 - 3.57) * (9 - 6.86) + (6 - 3.57) * (5 - 6.86) + (2 - 3.57) * (7 - 6.86) + (4 - 3.57) * (6 - 6.86)
#
# Step 4: Calculate the sum of the products of differences.
#
# Sum of Products = (2 - 3.57) * (7 - 6.86) + (3 - 3.57) * (8 - 6.86) + (5 - 3.57) * (6 - 6.86) + (4 - 3.57) * (9 - 6.86) + (6 - 3.57) * (5 - 6.86) + (2 - 3.57) * (7 - 6.86) + (4 - 3.57) * (6 - 6.86)
#
# Step 5: Calculate the sum of squared differences for employee tenure.
#
# Sum of Squared Differences for Employee Tenure = (2 - 3.57)^2 + (3 - 3.57)^2 + (5 - 3.57)^2 + (4 - 3.57)^2 + (6 - 3.57)^2 + (2 - 3.57)^2 + (4 - 3.57)^2
#
# Step 6: Calculate the sum of squared differences for job satisfaction.
#
# Sum of Squared Differences for Job Satisfaction = (7 - 6.86)^2

# %% [markdown]
# ### 9. Scenario: A study is conducted to compare the effectiveness of two different medications. The recovery times of the patients in each group are as follows:
#
#    Medication A: [10, 12, 14, 11, 13]
#
#    Medication B: [15, 17, 16, 14, 18]
#
#    Perform an analysis of variance (ANOVA) to determine if there is a significant difference in the mean recovery times between the two medications.

# %% [markdown]
# ### perform the ANOVA using the given data:
#
# Medication A: [10, 12, 14, 11, 13]
#
# Medication B: [15, 17, 16, 14, 18]
#
# Step 1: Calculate the means of both groups.
#
# Mean of Medication A = (10 + 12 + 14 + 11 + 13) / 5 = 12
#
# Mean of Medication B = (15 + 17 + 16 + 14 + 18) / 5 = 16
#
# Step 2: Calculate the sum of squares within each group (SSW).
#
# SSW for Medication A = (10 - 12)^2 + (12 - 12)^2 + (14 - 12)^2 + (11 - 12)^2 + (13 - 12)^2
#
# SSW for Medication B = (15 - 16)^2 + (17 - 16)^2 + (16 - 16)^2 + (14 - 16)^2 + (18 - 16)^2
#
# Step 3: Calculate the sum of squares between groups (SSB).
#
# SSB = ((12 - 14)^2 + (12 - 14)^2 + (12 - 14)^2 + (12 - 14)^2 + (12 - 14)^2) + ((16 - 14)^2 + (16 - 14)^2 + (16 - 14)^2 + (16 - 14)^2 + (16 - 14)^2) / 2
#
# Step 4: Calculate the degrees of freedom between groups (dfB).
#
# dfB = Number of groups - 1 = 2 - 1 = 1
#
# Step 5: Calculate the degrees of freedom within groups (dfW).
#
# dfW = Total number of data points - Number of groups = 5 + 5 - 2 = 8
#
# Step 6: Calculate the mean squares between groups (MSB).
#
# MSB = SSB / dfB
#
# Step 7: Calculate the mean squares within groups (MSW).
#
# MSW = SSW / dfW
#
# Step 8: Calculate the F-statistic.
#
# F = MSB / MSW
#
# Step 9: Determine the critical F-value or p-value for the desired significance level (alpha) and degrees of freedom. Assuming a significance level of 0.05 (5%), we can consult an F-table or use statistical software to find the critical F-value or p-value.
#
# Step 10: Compare the calculated F-statistic with the critical F-value or p-value to make a decision.

# %% [markdown]
# ### 10. Scenario: A company wants to analyze customer feedback ratings on a scale of 1 to 10. The data collected is
#
#  as follows:
#
#     [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#
#     Calculate the 75th percentile of the feedback ratings.

# %% [markdown]
# ### To calculate the 75th percentile of the feedback ratings, you need to arrange the ratings in ascending order and then find the value that is greater than or equal to 75% of the data. In this case, the data set is [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]. Let's find the 75th percentile:
#
# Step 1: Arrange the ratings in ascending order: [6, 7, 7, 8, 8, 8, 8, 9, 9, 10]
#
# Step 2: Calculate the index of the 75th percentile:
#
#     Index = (75/100) * (n-1) + 1
#
#     where n is the total number of data points.
#
# - Index = (75/100) * (10-1) + 1
# - Index = (75/100) * 9 + 1
# - Index = 6.75 + 1
# - Index = 7.75
#
# Step 3: Determine the value at the 7.75th index by taking the average of the values at indices 7 and 8:
#
# 75th percentile = (7th value + 8th value) / 2
#
# 75th percentile = (8 + 9) / 2
#
# 75th percentile = 8.5
#
# Therefore, the 75th percentile of the feedback ratings is 8.5.

# %% [markdown]
# ### 11. Scenario: A quality control department wants to test the weight consistency of a product. The weights of a sample of products are as follows:
#     [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#
#     Perform a hypothesis test to determine if the mean weight differs significantly from 10 grams.

# %% [markdown]
# ### Ans:- Weights of the sample of products: [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#
# Step 1: Calculate the mean of the sample weights.
#
# Mean = (10.2 + 9.8 + 10.0 + 10.5 + 10.3 + 10.1) / 6 = 10.17 (rounded to two decimal places)
#
# Step 2: Calculate the standard deviation of the sample weights.
#
# Standard deviation = 0.266 (rounded to three decimal places)
#
# Step 3: Calculate the standard error of the mean using the formula:
#
# Standard error = Standard deviation / sqrt(sample size)
#
# Standard error = 0.266 / sqrt(6) ≈ 0.109
#
# Step 4: Calculate the t-statistic using the formula:
#
# t = (Sample mean - Hypothesized mean) / Standard error
#
# t = (10.17 - 10) / 0.109 ≈ 1.56
#
# Step 5: Determine the degrees of freedom (df) using the formula:
#
# df = sample size - 1 = 6 - 1 = 5
#
# Step 6: Determine the critical t-value or p-value for the desired significance level (alpha) and degrees of freedom. Assuming a significance level of 0.05 (5%), we can consult a t-table or use statistical software to find the critical t-value or p-value.
#
# Step 7: Compare the calculated t-statistic with the critical t-value or p-value to make a decision.

# %% [markdown]
# ### 12. Scenario: A company wants to analyze the click-through rates of two different website designs. The number of clicks for each design is as follows:
#
#     Design A: [100, 120, 110, 90, 95]
#
#     Design B: [80, 85, 90, 95, 100]
#
#     Perform a chi-square test to determine if there is a significant difference in the click-through rates between the two designs.

# %% [markdown]
# ### Ans:- Design A: [100, 120, 110, 90, 95]
# Design B: [80, 85, 90, 95, 100]
#
# Step 1: Create a contingency table with the observed frequencies for each design.
# Contingency Table:
# - | Design A | Design B |
# - Clicks | 100 | 80 |
# - | 120 | 85 |
# - | 110 | 90 |
# - | 90 | 95 |
# - | 95 | 100 |
#
# Step 2: Calculate the expected frequencies under the assumption of independence between the designs. To do this, we need to calculate the row totals, column totals, and the overall total.
#
# Row Totals:
#
# Row Total for Design A = 100 + 120 + 110 + 90 + 95 = 515
#
# Row Total for Design B = 80 + 85 + 90 + 95 + 100 = 450
#
# Column Totals:
#
# Column Total for Design A = 100 + 120 + 110 + 90 + 95 = 515
#
# Column Total for Design B = 80 + 85 + 90 + 95 + 100 = 450
#
# Overall Total:
#
# Overall Total = 515 + 450 = 965
#
# Expected Frequencies:
#
# Expected Frequency for each cell = (Row Total * Column Total) / Overall Total
#
# Expected Frequency for Design A, Clicks = (515 * 515) / 965 ≈ 274.32
#
# Expected Frequency for Design B, Clicks = (450 * 515) / 965 ≈ 240.68
#
# Step 3: Calculate the chi-square test statistic using the formula:
#
# χ² = Σ ((Observed Frequency - Expected Frequency)² / Expected Frequency)
#
# χ² = ((100 - 274.32)² / 274.32) + ((120 - 274.32)² / 274.32) + ((110 - 274.32)² / 274.32) + ((90 - 274.32)² / 274.32) + ((95 - 274.32)² / 274.32) + ((80 - 240.68)² / 240.68) + ((85 - 240.68)² / 240.68) + ((90 - 240.68)² / 240.68) + ((95 - 240.68)² / 240.68) + ((100 - 240.68)² / 240.68)
#
# Step 4: Determine the degrees of freedom (df) using the formula:
#
# df = (Number of Rows - 1) * (Number of Columns - 1)
#
# df = (5 - 1) * (2 - 1) = 4
#
# Step 5: Determine the critical chi-square value or p-value for the desired significance level (alpha) and degrees of freedom. Assuming a significance level of 0.05 (5%), we can consult a chi-square table or use statistical software to find the critical chi-square value or p-value.
#
# Step 6: Compare the calculated chi-square test statistic with the critical chi-square

# %% [markdown]
# ### 13. Scenario: A survey is conducted to measure customer satisfaction with a product on a scale of 1 to 10. The data collected is as follows:
#     [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#
#     Calculate the 95% confidence interval for the population mean satisfaction score.

# %% [markdown]
# ### Ans:-To calculate the 95% confidence interval for the population mean satisfaction score, you can use the formula:
#
# Confidence Interval = Sample Mean ± (Critical Value * Standard Error)
#
# Let's calculate the confidence interval using the given data:
#
# Satisfaction scores: [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#
# Step 1: Calculate the sample mean.
#
# Sample Mean = (7 + 9 + 6 + 8 + 10 + 7 + 8 + 9 + 7 + 8) / 10 = 7.9
#
# Step 2: Calculate the standard deviation of the sample.
#
# Standard Deviation = 1.169 (rounded to three decimal places)
#
# Step 3: Calculate the standard error of the mean using the formula:
#
# Standard Error = Standard Deviation / sqrt(sample size)
#
# Standard Error = 1.169 / sqrt(10) ≈ 0.37
#
# Step 4: Determine the critical value for a 95% confidence level. For a two-tailed test and a sample size of 10, the critical value can be obtained from a t-distribution table or using statistical software. For a 95% confidence level with a sample size of 10, the critical value is approximately 2.262.
#
# Step 5: Calculate the confidence interval.
#
# Confidence Interval = Sample Mean ± (Critical Value * Standard Error)
#
# Confidence Interval = 7.9 ± (2.262 * 0.37)
#
# Lower Bound = 7.9 - (2.262 * 0.37) ≈ 7.13
#
# Upper Bound = 7.9 + (2.262 * 0.37) ≈ 8.67
#
# Therefore, the 95% confidence interval for the population mean satisfaction score is approximately 7.13 to 8.67.

# %% [markdown]
# ### 14. Scenario: A company wants to analyze the effect of temperature on product performance. The data collected is as follows:
#
#     Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
#
#     Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
#     Perform a simple linear regression to predict performance based on temperature.

# %% [markdown]
# ### Ans:- Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
# Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Temperature = (20 + 22 + 23 + 19 + 21) / 5 = 21
#
# Mean of Performance = (8 + 7 + 9 + 6 + 8) / 5 = 7.6
#
# Step 2: Calculate the differences from the means for each data point.
#
# Differences for Temperature = [20 - 21, 22 - 21, 23 - 21, 19 - 21, 21 - 21]
#
# Differences for Performance = [8 - 7.6, 7 - 7.6, 9 - 7.6, 6 - 7.6, 8 - 7.6]
#
# Step 3: Calculate the product of the differences for each data point.
#
# Product of Differences = (20 - 21) * (8 - 7.6) + (22 - 21) * (7 - 7.6) + (23 - 21) * (9 - 7.6) + (19 - 21) * (6 - 7.6) + (21 - 21) * (8 - 7.6)
#
# Step 4: Calculate the sum of the products of differences.
#
# Sum of Products = (20 - 21) * (8 - 7.6) + (22 - 21) * (7 - 7.6) + (23 - 21) * (9 - 7.6) + (19 - 21) * (6 - 7.6) + (21 - 21) * (8 - 7.6)
#
# Step 5: Calculate the sum of squared differences for temperature.
#
# Sum of Squared Differences for Temperature = (20 - 21)^2 + (22 - 21)^2 + (23 - 21)^2 + (19 - 21)^2 + (21 - 21)^2
#
# Step 6: Calculate the sum of squared differences for performance.
#
# Sum of Squared Differences for Performance = (8 - 7.6)^2 + (7 - 7.6)^2 + (9 - 7.6)^2 + (6 - 7.6)^2 + (8 - 7.6)^2
#
# Step 7: Calculate the slope of the regression line using the formula:
#
# Slope = Sum of Products / Sum of Squared Differences for Temperature
#
# Step 8: Calculate the intercept of the regression line using the formula:
#
# Intercept = Mean of Performance - (Slope * Mean of Temperature)
#
# Step 9: Determine the equation of the regression line:
#
# Regression Line: Performance = Slope * Temperature + Intercept
#
# Step 10: Use the equation of the regression line to make predictions about performance for different temperatures.

# %% [markdown]
# ### 15. Scenario: A study is conducted to compare the preferences of two groups of participants. The preferences are measured on a Likert scale from 1 to 5. The data collected is as follows:
#
#     Group A: [4, 3, 5, 2, 4]
#
#     Group B: [3, 2, 4, 3, 3]
#
#     Perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between the two groups.

# %% [markdown]
# ### Ans:- To perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between Group A and Group B, we can use the following steps:
#
# Step 1: State the null hypothesis (H0) and the alternative hypothesis (H1):
#
# H0: There is no significant difference in the median preferences between the two groups.
#
# H1: There is a significant difference in the median preferences between the two groups.
#
# Step 2: Rank the data from both groups together, starting from the smallest value and assigning ranks based on their order.
#
# Group A: [4, 3, 5, 2, 4]
#
# Group B: [3, 2, 4, 3, 3]
#
# Combined and ranked data: [2, 2, 3, 3, 3, 4, 4, 5]
#
# Step 3: Calculate the sum of ranks for each group.
#
# Sum of ranks for Group A = 4 + 3 + 7 + 1 + 5 = 20
#
# Sum of ranks for Group B = 3 + 1 + 5 + 3 + 3 = 15
#
# Step 4: Calculate the U statistic for each group.
#
# U statistic for Group A = n1 * n2 + (n1 * (n1 + 1)) / 2 - Sum of ranks for Group A
#
# = 5 * 5 + (5 * (5 + 1)) / 2 - 20
#
# = 25 + (5 * 6) / 2 - 20
#
# = 25 + 15 - 20
#
# = 20
#
# U statistic for Group B = n1 * n2 + (n1 * (n1 + 1)) / 2 - Sum of ranks for Group B
#
# = 5 * 5 + (5 * (5 + 1)) / 2 - 15
#
# = 25 + (5 * 6) / 2 - 15
#
# = 25 + 15 - 15
#
# = 25
#
# Step 5: Calculate the minimum U value (Umin) and the maximum U value (Umax).
#
# Umin = min(U statistic for Group A, U statistic for Group B) = min(20, 25) = 20
#
# Umax = max(U statistic for Group A, U statistic for Group B) = max(20, 25) = 25
#
# Step 6: Determine the critical U value or p-value for the desired significance level (alpha). The critical U value can be obtained from a Mann-Whitney U table or using statistical software. For a 95% confidence level (alpha = 0.05) and a two-tailed test, the critical U value is 5.
#
# Step 7: Compare the Umin and Umax values with the critical U value to make a decision.

# %% [markdown]
# ### 16. Scenario: A company wants to analyze the distribution of customer ages. The data collected is as follows:
#     [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
#     Calculate the interquartile range (IQR) of the ages.

# %% [markdown]
# ### Ans:- To calculate the interquartile range (IQR) of the ages, you need to determine the values of the first quartile (Q1) and the third quartile (Q3). The IQR is then calculated by subtracting Q1 from Q3.
#
# Given the data: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 1: Arrange the data in ascending order: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70].
#
# Step 2: Calculate the position of the first quartile (Q1):
#
# Position of Q1 = (1 / 4) * (n + 1)
#
# where n is the total number of data points.
#
# Position of Q1 = (1 / 4) * (10 + 1) = 2.75
#
# Step 3: Determine the values at positions 2 and 3 and calculate the value of Q1 by interpolation:
#
# Q1 = Value at position 2 + (Position of Q1 - 2) * (Value at position 3 - Value at position 2)
#
# Q1 = 30 + (2.75 - 2) * (35 - 30) = 30 + 0.75 * 5 = 30 + 3.75 = 33.75
#
# Step 4: Calculate the position of the third quartile (Q3):
#
# Position of Q3 = (3 / 4) * (n + 1)
#
# Position of Q3 = (3 / 4) * (10 + 1) = 8.25
#
# Step 5: Determine the values at positions 8 and 9 and calculate the value of Q3 by interpolation:
#
# Q3 = Value at position 8 + (Position of Q3 - 8) * (Value at position 9 - Value at position 8)
#
# Q3 = 60 + (8.25 - 8) * (65 - 60) = 60 + 0.25 * 5 = 60 + 1.25 = 61.25
#
# Step 6: Calculate the interquartile range (IQR) by subtracting Q1 from Q3:
#
# IQR = Q3 - Q1 = 61.25 - 33.75 = 27.5
#
# Therefore, the interquartile range (IQR) of the ages is 27.5.

# %% [markdown]
# ### 17. Scenario: A study is conducted to compare the performance of three different machine learning algorithms. The accuracy scores for each algorithm are as follows:
#
#     Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
#
#     Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
#
#     Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#
#     Perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the algorithms.

# %% [markdown]
# ### Ans:- To perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the algorithms, we can use the following steps:
#
# Step 1: State the null hypothesis (H0) and the alternative hypothesis (H1):
#
# H0: There is no significant difference in the median accuracy scores between the algorithms.
#
# H1: There is a significant difference in the median accuracy scores between the algorithms.
#
# Step 2: Combine the accuracy scores from all algorithms and rank them in ascending order.
#
# Combined and ranked data:
#
# [0.78, 0.79, 0.80, 0.80, 0.82, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.87, 0.88, 0.89, 0.90]
#
# Step 3: Calculate the sum of ranks for each algorithm.
#
# Sum of ranks for Algorithm A = 8 + 9 + 5 + 12 + 6 = 40
#
# Sum of ranks for Algorithm B = 1 + 3 + 7 + 2 + 4 = 17
#
# Sum of ranks for Algorithm C = 15 + 13 + 11 + 10 + 14 = 63
#
# Step 4: Calculate the test statistic using the formula:
#
# H = (12 / (n * (n + 1))) * (Σ(R^2 / n) - (n * (n + 1)^2 / 4))
#
# where n is the total number of observations and R is the sum of ranks for each algorithm.
#
# H = (12 / (15 * (15 + 1))) * ((40^2 / 5) + (17^2 / 5) + (63^2 / 5) - (15 * (15 + 1)^2 / 4))
#
# H = (12 / (15 * 16)) * (160 + 57 + 396 - (15 * 16^2 / 4))
#
# H = (12 / 240) * (613 - 480)
#
# H = 0.05 * 133
#
# H = 6.65
#
# Step 5: Determine the critical value or p-value for the desired significance level (alpha) and degrees of freedom. Assuming a significance level of 0.05 (5%), we can consult a Kruskal-Wallis table or use statistical software to find the critical value or p-value.
#
# Step 6: Compare the test statistic with the critical value or p-value to make a decision.

# %% [markdown]
# ### 18. Scenario: A company wants to analyze the effect of price on sales. The data collected is as follows:
#     Price (in dollars): [10, 15, 12, 8, 14]
#     Sales: [100, 80, 90, 110, 95]
#     Perform a simple linear regression to predict

# %% [markdown]
# ### Ans:- To perform a simple linear regression to predict sales based on price, you can use the least squares method to find the equation of the regression line. The equation will allow you to make predictions about sales for different price values.
#
# Let's perform the simple linear regression analysis using the given data:
#
# Price (in dollars): [10, 15, 12, 8, 14]
#
# Sales: [100, 80, 90, 110, 95]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Price = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of Sales = (100 + 80 + 90 + 110 + 95) / 5 = 95
#
# Step 2: Calculate the differences from the means for each data point.
#
# Differences for Price = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8]
#
# Differences for Sales = [100 - 95, 80 - 95, 90 - 95, 110 - 95, 95 - 95]
#
# Step 3: Calculate the product of the differences for each data point.
#
# Product of Differences = (10 - 11.8) * (100 - 95) + (15 - 11.8) * (80 - 95) + (12 - 11.8) * (90 - 95) + (8 - 11.8) * (110 - 95) + (14 - 11.8) * (95 - 95)
#
# Step 4: Calculate the sum of the products of differences.
#
# Sum of Products = (10 - 11.8) * (100 - 95) + (15 - 11.8) * (80 - 95) + (12 - 11.8) * (90 - 95) + (8 - 11.8) * (110 - 95) + (14 - 11.8) * (95 - 95)
#
# Step 5: Calculate the sum of squared differences for price.
#
# Sum of Squared Differences for Price = (10 - 11.8)^2 + (15 - 11.8)^2 + (12 - 11.8)^2 + (8 - 11.8)^2 + (14 - 11.8)^2
#
# Step 6: Calculate the sum of squared differences for sales.
#
# Sum of Squared Differences for Sales = (100 - 95)^2 + (80 - 95)^2 + (90 - 95)^2 + (110 - 95)^2 + (95 - 95)^2
#
# Step 7: Calculate the slope of the regression line using the formula:
#
# Slope = Sum of Products / Sum of Squared Differences for Price
#
# Step 8: Calculate the intercept of the regression line using the formula:
#
# Intercept = Mean of Sales - (Slope * Mean of Price)
#
# Step 9: Determine the equation of the regression line:
#
# Regression Line: Sales = Slope * Price + Intercept
#
# Step 10: Use the equation of the regression line to make predictions about sales for different price values.

# %% [markdown]
# ### 19. Scenario: A survey is conducted to measure the satisfaction levels of customers with a new product. The data collected is as follows:
#     [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#     Calculate the standard error of the mean satisfaction score.

# %% [markdown]
# ### Ans:- To calculate the standard error of the mean satisfaction score,
#
# Standard Error = Standard Deviation / sqrt(n)
#
# where the Standard Deviation is a measure of the variability in the data, and n is the sample size.
#
# Given the data: [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#
# Step 1: Calculate the mean of the satisfaction scores.
#
# Mean = (7 + 8 + 9 + 6 + 8 + 7 + 9 + 7 + 8 + 7) / 10 = 7.6
#
# Step 2: Calculate the differences between each satisfaction score and the mean.
#
# Differences = [7 - 7.6, 8 - 7.6, 9 - 7.6, 6 - 7.6, 8 - 7.6, 7 - 7.6, 9 - 7.6, 7 - 7.6, 8 - 7.6, 7 - 7.6]
#
# Step 3: Calculate the squared differences.
#
# Squared Differences = [(7 - 7.6)^2, (8 - 7.6)^2, (9 - 7.6)^2, (6 - 7.6)^2, (8 - 7.6)^2, (7 - 7.6)^2, (9 - 7.6)^2, (7 - 7.6)^2, (8 - 7.6)^2, (7 - 7.6)^2]
#
# Step 4: Calculate the variance by summing up the squared differences and dividing by (n - 1).
#
# Variance = ( (7 - 7.6)^2 + (8 - 7.6)^2 + (9 - 7.6)^2 + (6 - 7.6)^2 + (8 - 7.6)^2 + (7 - 7.6)^2 + (9 - 7.6)^2 + (7 - 7.6)^2 + (8 - 7.6)^2 + (7 - 7.6)^2 ) / (10 - 1)
#
# Step 5: Calculate the standard deviation by taking the square root of the variance.
#
# Standard Deviation = sqrt(Variance)
#
# Step 6: Calculate the standard error of the mean by dividing the standard deviation by sqrt(n).
#
# Standard Error = Standard Deviation / sqrt(n)

# %% [markdown]
# ### 20. Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
#     Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#     Sales (in thousands): [25, 30, 28, 20, 26]
#     Perform a multiple regression analysis to predict sales based on advertising expenditure.

# %% [markdown]
# ### Ans:- Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 1: Set up the regression model with the dependent variable (sales) and independent variable (advertising expenditure).
#
# Sales = β₀ + β₁ * Advertising Expenditure
#
# Step 2: Calculate the means of both variables.
#
# Mean of Advertising Expenditure = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of Sales = (25 + 30 + 28 + 20 + 26) / 5 = 25.8
#
# Step 3: Calculate the differences from the means for each data point.
#
# Differences for Advertising Expenditure = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8]
#
# Differences for Sales = [25 - 25.8, 30 - 25.8, 28 - 25.8, 20 - 25.8, 26 - 25.8]
#
# Step 4: Calculate the product of the differences for each data point.
#
# Product of Differences = (10 - 11.8) * (25 - 25.8) + (15 - 11.8) * (30 - 25.8) + (12 - 11.8) * (28 - 25.8) + (8 - 11.8) * (20 - 25.8) + (14 - 11.8) * (26 - 25.8)
#
# Step 5: Calculate the sum of the products of differences.
#
# Sum of Products = (10 - 11.8) * (25 - 25.8) + (15 - 11.8) * (30 - 25.8) + (12 - 11.8) * (28 - 25.8) + (8 - 11.8) * (20 - 25.8) + (14 - 11.8) * (26 - 25.8)
#
# Step 6: Calculate the sum of squared differences for advertising expenditure.
#
# Sum of Squared Differences for Advertising Expenditure = (10 - 11.8)^2 + (15 - 11.8)^2 + (12 - 11.8)^2 + (8 - 11.8)^2 + (14 - 11.8)^2
#
# Step 7: Calculate the sum of squared differences for sales.
#
# Sum of Squared Differences for Sales = (25 - 25.8)^2 + (30 - 25.8)^2 + (28 - 25.8)^2 + (20 - 25.8)^2 + (26 - 25.8)^2
#
# Step 8: Calculate the slope of the regression line using the formula:
#
# β₁ = Sum of Products / Sum of Squared Differences for Advertising Expenditure
#
# Step 9: Calculate the intercept of the regression line using the formula:
#
# β₀ = Mean of Sales - (β₁ * Mean of Advertising Expenditure)
#
# Step 10: Determine the equation of the regression line
